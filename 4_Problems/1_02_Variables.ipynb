# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_02_Variables.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Job Postings Count (1.2.1)

# %%
job_count=10

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Job Information (1.2.2)

# %%
job_info="Web Developer"

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Calculate Total Compensation (1.2.3)

# %%
compensation=5000
total_compensation=job_count*compensation
total_compensation
# Out:
# 50000

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Calculate Monthly Salary (1.2.4)

# %%
annual_salary=100000
monthly_salary=annual_salary/12
monthly_salary
# Out:
# 8333.333333333334

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Calculate Total Compensation with Bonus (1.2.5)

# %%
bonus=2000
total_compensation_bon=total_compensation+ bonus
total_compensation_bon
# Out:
# 52000

# %% [markdown]
# ---
